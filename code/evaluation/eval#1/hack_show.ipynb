# %%
OLD_PATH = "/home/fabian/uni/Bachelorarbeit/bachelorarbeit-fabian-alich/code/evaluation/benchmark"
NEW_PATH = "/home/fabian/uni/Bachelorarbeit/bachelorarbeit-fabian-alich/code/evaluation/benchmark_fehlerhaft"

# %%
import os
from dataclasses import asdict

from dc_triangulation import (
    SAT,
    SAT_TRI,
    Gurobi,
    Gurobi_Parameter,
    Gurobi_Tri,
    Gurobi_Tri_Parameter,
    Ortools,
    Ortools_Parameter,
    OrTools_Tri,
    Ortools_Tri_Parameter,
    Run_Algbench,
    SAT_Parameter,
    SAT_Tri_Parameter,
)

TIMEOUT = 300
path = "/home/fabian/uni/Bachelorarbeit/bachelorarbeit-fabian-alich/code/evaluation/eval#1/instances_copy"
figure_path = "/home/fabian/uni/Bachelorarbeit/bachelorarbeit-fabian-alich/code/evaluation/eval#1/figures"
HOST = ["algry01", "algry02", "algry03", "algry04"]
